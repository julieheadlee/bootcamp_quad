# %% [markdown]
# # Marijuana Tax Revenue
#
# Starting every Fiscal Year(FY) dating back to 2015, the first 40 million of the Retail Marijuana Excise Tax revenue was distributed back to the Public School Capital Construction Assistance Fund (PSCCAF).  Any excess will be transferred to the Public School Fund.  This has provided over 200 Million of assistance to grow the education system in a 5-year period.
#
# Of the marijuana tax revenue already collected, the Colorado joint budget committee set aside 2.5 million to increase the number of health professionals in Colorado public schools.  In November 2014, the state awarded the first 975,000 in grants to Colorado schools to be used to hire health professionals.
#
# The funds help fill a critical gap in Colorado school districts, which suffer from a shortage of school health workers due to 2011 budget cuts.  Many of the newly hired health workers, including nurses and social workers, will focus on mental health support and on programs to educate students about drug use.
#
# The marijuana tax cash fund (71.85% of the 90% State Share), which receives the largest share of cannabis-related revenue, must be used for health care, health education, substance abuse prevention and treatment programs, and law enforcement.

# %%
#Dependencies and setup
import matplotlib
import matplotlib.pyplot as plt
import datetime as dt
from matplotlib.dates import DateFormatter
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
#Load Marijuana Tax Revenue csv
tax_df = pd.read_csv("Resources/marijuana_tax.csv", dtype="object", encoding="utf-8")
tax_df
# Out:
#          Date State Sales Tax Retail Sales Tax  Retail Excise Tax (15%)  \
# 0    2/1/2014     $1,330,209        $1,401,568                $195,318
# 1    3/1/2014     $1,460,429        $1,434,916                $339,615
# 2    4/1/2014     $1,569,405        $1,898,685                $609,907
# 3    5/1/2014     $1,559,710        $2,217,607                $734,351
# 4    6/1/2014     $1,569,454        $2,070,577              $1,135,648
# ..        ...             ...               ...                     ...
# 76   6/1/2020     $1,287,667       $22,814,211              $8,454,927
# 77   7/1/2020     $1,288,715       $24,644,660              $9,381,481
# 78   8/1/2020     $1,433,419       $27,794,380             $10,470,917
# 79   9/1/2020     $1,339,939       $26,656,923              $9,682,085
# 80  10/1/2020     $1,170,328       $24,593,888              $8,821,260
#
#    License & Fees Total Taxes & Fees    Total to Date
# 0       $592,661         $3,519,756       $3,519,756
# 1       $857,615         $4,092,575       $7,612,330
# 2       $902,995         $4,980,992      $12,593,322
# 3       $761,687         $5,273,355      $17,866,677
# 4       $940,028         $5,715,707      $23,582,384
# ..            ...                ...              ...
# 76    $1,067,803        $33,624,609   $1,375,145,032
# 77      $814,882        $36,129,738   $1,411,274,770
# 78      $996,898        $40,695,613   $1,451,970,383
# 79      $947,467        $38,626,414   $1,490,596,797
# 80      $824,817        $35,410,293   $1,526,007,090
#
# [81 rows x 7 columns]

# %%
# Get data correctly from pandas
dates = tax_df["Date"].values
x_values = [dt.datetime.strptime(date, '%m/%d/%Y').date() for date in dates]
y_values1 = tax_df["State Sales Tax"].replace('[\$,]', '', regex=True).astype(float)
#y_values2 = tax_df["Retail Sales Tax"].replace('[\$,]', '', regex=True).astype(float)
y_values3 = tax_df["Retail Excise Tax (15%)"].replace('[\$,]', '', regex=True).astype(float)
y_values4 = tax_df["License & Fees"].replace('[\$,]', '', regex=True).astype(float)
y_values5 = tax_df["Total to Date"].replace('[\$,]', '', regex=True).astype(float)

ax = plt.axes()
date_form = DateFormatter("%Y")
ax.xaxis.set_major_formatter(date_form)
#plt.xticks(rotation=70)

# Adjusts number of Y-ticks
#yloc = plt.MaxNLocator(40)
#ax.yaxis.set_major_locator(yloc)

# X
#xloc = plt.MaxNLocator(40)
#ax.xaxis.set_major_locator(xloc)

x = [2014, 2015, 2016, 2017, 2018, 2019, 2020]
y = [0, 50, 100, 150, 200, 250, 300]

x_ticks = np.arange(2014, 2021, 1)
plt.xticks(x_ticks)

y_ticks = np.arange(0, 350, 50)
plt.yticks(y_ticks)

plt.plot(x, y)

#loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
#ax.xaxis.set_major_locator(x_values)
#ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1)) 

#plt.show()

# Plots data
plt.plot(x_values, tax_df["State Sales Tax"], label = "State")
#plt.plot(x_values, tax_df["Retail Sales Tax"], label = "Retail")
plt.plot(x_values, tax_df["Retail Excise Tax (15%)"], label = "Excise (15%)")
plt.plot(x_values, tax_df["License & Fees"], label = "License & Fee")
plt.plot(x_values, tax_df["Total to Date"], label = "Total Revenue")

#create title, xaxis, and yaxis
plt.title("Revenue Marijuana Tax")
plt.xlabel("Sales Month")
plt.ylabel("Revenue")
plt.tight_layout()

# plays with size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# Legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=5)

plt.show()
