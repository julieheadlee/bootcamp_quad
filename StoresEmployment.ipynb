# %% [markdown]
# Employement and Store Types/Locations

# %%
# Dependencies
from config import gkey
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import gmaps

# %%
# Read CSV
CO_Medical = pd.read_csv("Data/Stores - Medical.csv")
CO_Retail = pd.read_csv("Data/Stores - Retail.csv")
Lat_Long = pd.read_csv("Data/us-zip-code-latitude-and-longitude.csv", sep=';')
State_Employment = pd.read_csv("Data/EmploymentByState.csv")

# %%
# Check Medical DataFrame
CO_Medical.head()
# Out:
#   LicenseNumber                               FacilityName               DBA  \
# 0     402-00001                              ALLGREENS LLC               NaN
# 1     402-00002  ALTERNATIVE MEDICINE ON CAPITOL HILL LLC                NaN
# 2     402-00005                                   P2C3 LLC  THE SECRET STASH
# 3     402-00008                      HERBAL OUTFITTERS LLC   THE GREEN JOINT
# 4     402-00011                           JGB VENTURES LLC             DANK
#
#   FacilityType              City  ZipCode DateUpdated
# 0          MMC            Denver    80204  2020-12-01
# 1          MMC            Denver    80218  2020-12-01
# 2          MMC  Colorado Springs    80904  2020-12-01
# 3          MMC             Rifle    81650  2020-12-01
# 4          MMC            Denver    80207  2020-12-01

# %%
# Check Retail Data Frame
CO_Retail.head()
# Out:
#   LicenseNumber                     FacilityName               DBA  \
# 0    402R-00004                 JGB VENTURES LLC              DANK
# 1    402R-00005  CANOSA PROPERTY INVESTMENTS LLC        BOTANICO 2
# 2    402R-00002                      CENTRAL LLC  BONFIRE CANNABIS
# 3    402R-00003               5110 SANCTUARY LLC         EVERBLOOM
# 4    402R-00007              L3ASTOCKCOMPLEX LLC           EUFLORA
#
#              FacilityType          City  ZipCode DateUpdated
# 0  Retail Marijuana Store        Denver    80207  2020-12-01
# 1  Retail Marijuana Store        Denver    80204  2020-12-01
# 2  Retail Marijuana Store  Central City    80427  2020-12-01
# 3  Retail Marijuana Store        Denver    80216  2020-12-01
# 4  Retail Marijuana Store        Denver    80216  2020-12-01

# %%
CO_All_Types = pd.concat([CO_Retail, CO_Medical])
CO_All_Types
# Out:
#     LicenseNumber                     FacilityName                        DBA  \
# 0      402R-00004                 JGB VENTURES LLC                       DANK
# 1      402R-00005  CANOSA PROPERTY INVESTMENTS LLC                 BOTANICO 2
# 2      402R-00002                      CENTRAL LLC           BONFIRE CANNABIS
# 3      402R-00003               5110 SANCTUARY LLC                  EVERBLOOM
# 4      402R-00007              L3ASTOCKCOMPLEX LLC                    EUFLORA
# ..            ...                              ...                        ...
# 426     402-01324                    EXIT 243 LLC         DISPENSARY EXIT 243
# 427     402-01331                 MAGGIES FARM LLC              MAGGIE'S FARM
# 428     402-01328        SISTEM COMMERCE CITY LLC   SILVER STEM FINE CANNABIS
# 429     402-01330                       2251SB LLC           APOTHECARY FARMS
# 430     402-01255              LIGHTSHADE LABS LLC                 LIGHTSHADE
#
#                FacilityType              City  ZipCode DateUpdated
# 0    Retail Marijuana Store            Denver    80207  2020-12-01
# 1    Retail Marijuana Store            Denver    80204  2020-12-01
# 2    Retail Marijuana Store      Central City    80427  2020-12-01
# 3    Retail Marijuana Store            Denver    80216  2020-12-01
# 4    Retail Marijuana Store            Denver    80216  2020-12-01
# ..                      ...               ...      ...         ...
# 426                     MMC     Idaho Springs    80452  2020-12-01
# 427                     MMC        Las Animas    81054  2020-12-01
# 428                     MMC     Commerce City    80022  2020-12-01
# 429                     MMC  Colorado Springs    80909  2020-12-01
# 430                     MMC   Federal Heights    80260  2020-12-01
#
# [1034 rows x 7 columns]

# %%
CO_Facility_Zip = CO_All_Types.groupby(['ZipCode','FacilityType']).size().reset_index(name='counts')
CO_Facility_Zip
# Out:
#      ZipCode            FacilityType  counts
# 0      80002  Retail Marijuana Store       1
# 1      80010  Retail Marijuana Store       5
# 2      80011  Retail Marijuana Store       5
# 3      80012  Retail Marijuana Store       2
# 4      80013  Retail Marijuana Store       1
# ..       ...                     ...     ...
# 246    81635  Retail Marijuana Store       7
# 247    81639  Retail Marijuana Store       1
# 248    81650                     MMC       2
# 249    81650  Retail Marijuana Store       2
# 250    81652  Retail Marijuana Store       2
#
# [251 rows x 3 columns]

# %%
# Check zip code data 
# Source - https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/export/?location=2,43.25174,-72.87322&basemap=jawg.streets
Lat_Long
# Out:
#          Zip             City State   Latitude   Longitude  Timezone  \
# 0      66025           Eudora    KS  38.917032  -95.064550        -6
# 1      74565          Savanna    OK  34.831398  -95.839670        -6
# 2      75631        Beckville    TX  32.237924  -94.464270        -6
# 3      92067  Rancho Santa Fe    CA  33.016492 -117.202640        -8
# 4      92119        San Diego    CA  32.802250 -117.024310        -8
# ...      ...              ...   ...        ...         ...       ...
# 43186  25612         Chauncey    WV  37.766620  -81.987550        -5
# 43187  59444           Galata    MT  48.635319 -111.240830        -7
# 43188  60532            Lisle    IL  41.789079  -88.085360        -6
# 43189  61638           Peoria    IL  40.796887  -89.611146        -6
# 43190  85326          Buckeye    AZ  33.354418 -112.569410        -7
#
#        Daylight savings time flag              geopoint
# 0                               1   38.917032,-95.06455
# 1                               1   34.831398,-95.83967
# 2                               1   32.237924,-94.46427
# 3                               1  33.016492,-117.20264
# 4                               1   32.80225,-117.02431
# ...                           ...                   ...
# 43186                           1    37.76662,-81.98755
# 43187                           1  48.635319,-111.24083
# 43188                           1   41.789079,-88.08536
# 43189                           1  40.796887,-89.611146
# 43190                           0  33.354418,-112.56941
#
# [43191 rows x 8 columns]

# %%
# Merge Store Data & With Zip Code
Master_Location_Data = CO_Facility_Zip.merge(Lat_Long, left_on ='ZipCode', right_on='Zip', how = 'left')
Master_Location_Data
# Out:
#      ZipCode            FacilityType  counts      Zip       City State  \
# 0      80002  Retail Marijuana Store       1  80002.0     Arvada    CO
# 1      80010  Retail Marijuana Store       5  80010.0     Aurora    CO
# 2      80011  Retail Marijuana Store       5  80011.0     Aurora    CO
# 3      80012  Retail Marijuana Store       2  80012.0     Aurora    CO
# 4      80013  Retail Marijuana Store       1  80013.0     Aurora    CO
# ..       ...                     ...     ...      ...        ...   ...
# 246    81635  Retail Marijuana Store       7  81635.0  Parachute    CO
# 247    81639  Retail Marijuana Store       1  81639.0     Hayden    CO
# 248    81650                     MMC       2  81650.0      Rifle    CO
# 249    81650  Retail Marijuana Store       2  81650.0      Rifle    CO
# 250    81652  Retail Marijuana Store       2  81652.0       Silt    CO
#
#       Latitude  Longitude  Timezone  Daylight savings time flag  \
# 0    39.795006 -105.09810      -7.0                         1.0
# 1    39.739387 -104.86210      -7.0                         1.0
# 2    39.739737 -104.80905      -7.0                         1.0
# 3    39.698387 -104.83956      -7.0                         1.0
# 4    39.659105 -104.77910      -7.0                         1.0
# ..         ...        ...       ...                         ...
# 246  39.493283 -108.11571      -7.0                         1.0
# 247  40.488060 -107.26093      -7.0                         1.0
# 248  39.603225 -107.89755      -7.0                         1.0
# 249  39.603225 -107.89755      -7.0                         1.0
# 250  39.508481 -107.66873      -7.0                         1.0
#
#                  geopoint
# 0     39.795006,-105.0981
# 1     39.739387,-104.8621
# 2    39.739737,-104.80905
# 3    39.698387,-104.83956
# 4     39.659105,-104.7791
# ..                    ...
# 246  39.493283,-108.11571
# 247   40.48806,-107.26093
# 248  39.603225,-107.89755
# 249  39.603225,-107.89755
# 250  39.508481,-107.66873
#
# [251 rows x 11 columns]

# %%
Master_Location_Data_Clean = Master_Location_Data.dropna()
Master_Location_Data_Clean
# Out:
#      ZipCode            FacilityType  counts      Zip       City State  \
# 0      80002  Retail Marijuana Store       1  80002.0     Arvada    CO
# 1      80010  Retail Marijuana Store       5  80010.0     Aurora    CO
# 2      80011  Retail Marijuana Store       5  80011.0     Aurora    CO
# 3      80012  Retail Marijuana Store       2  80012.0     Aurora    CO
# 4      80013  Retail Marijuana Store       1  80013.0     Aurora    CO
# ..       ...                     ...     ...      ...        ...   ...
# 246    81635  Retail Marijuana Store       7  81635.0  Parachute    CO
# 247    81639  Retail Marijuana Store       1  81639.0     Hayden    CO
# 248    81650                     MMC       2  81650.0      Rifle    CO
# 249    81650  Retail Marijuana Store       2  81650.0      Rifle    CO
# 250    81652  Retail Marijuana Store       2  81652.0       Silt    CO
#
#       Latitude  Longitude  Timezone  Daylight savings time flag  \
# 0    39.795006 -105.09810      -7.0                         1.0
# 1    39.739387 -104.86210      -7.0                         1.0
# 2    39.739737 -104.80905      -7.0                         1.0
# 3    39.698387 -104.83956      -7.0                         1.0
# 4    39.659105 -104.77910      -7.0                         1.0
# ..         ...        ...       ...                         ...
# 246  39.493283 -108.11571      -7.0                         1.0
# 247  40.488060 -107.26093      -7.0                         1.0
# 248  39.603225 -107.89755      -7.0                         1.0
# 249  39.603225 -107.89755      -7.0                         1.0
# 250  39.508481 -107.66873      -7.0                         1.0
#
#                  geopoint
# 0     39.795006,-105.0981
# 1     39.739387,-104.8621
# 2    39.739737,-104.80905
# 3    39.698387,-104.83956
# 4     39.659105,-104.7791
# ..                    ...
# 246  39.493283,-108.11571
# 247   40.48806,-107.26093
# 248  39.603225,-107.89755
# 249  39.603225,-107.89755
# 250  39.508481,-107.66873
#
# [247 rows x 11 columns]

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
# Store Lat & Long into  locations 
locations = Master_Location_Data_Clean[["Latitude", "Longitude"]]

# Convert # of locations to float and store

Count_of_locations = Master_Location_Data_Clean["counts"].astype(float)

# %%
# Create a loation Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=Count_of_locations, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
CO_Facility_Weight = CO_All_Types.groupby(['FacilityType']).size().reset_index(name='counts')
CO_Facility_Weight
# Out:
#              FacilityType  counts
# 0                     MMC     431
# 1  Retail Marijuana Store     603

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = CO_Facility_Weight['FacilityType']
sizes = CO_Facility_Weight['counts']
explode = (0,0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title("% of Facility Type")
plt.savefig('Images/FacilityPie.png', dpi=300)

plt.show()

# %%
State_Employment
# Out:
#     2017   2018   2019   2020
# 0  23407  26891  31486  34705

# %%
row = State_Employment.iloc[0]
row.plot(kind='line', xlabel='Year', ylabel='Number Employed in Cannabis Job')
plt.title('Coloardo Cannabis Jobs By Year  (Source: Leafly)')
plt.savefig('Images/Employment.png', dpi=300)
plt.show()
